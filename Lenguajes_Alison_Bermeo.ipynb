# %% [markdown]
# <a href="https://colab.research.google.com/github/zuleicab26-collab/Hola-mundo/blob/master/Lenguajes_Alison_Bermeo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Lenguaje Phython

# %% [markdown]
# Es un lenguaje de programaciòn facil de entender y leer, se utiliza para crear aplicaciones, pàgunas web,etc. Su sintaxis es sencilla lo que la hace una buena opciòn.

# %%
print("Hola mundo")
# Out:
# Hola mundo

# %% [markdown]
# Luenguaje R

# %% [markdown]
# Es un lenguaje de programaciòn renfocado principalmente en estadistica y gràficos

# %%
print("Hola mundo")
# Out:
# Hola mundo

# %% [markdown]
# Lenguaje JavaScript

# %% [markdown]
# Lenguaje de programaciòn utilizado para desarrollar aplicaciònes web, mòviles de escritorio y empresariales. Conocido por ser seguro y portàtil.

# %%
# %%javascript
# console.log("Hola mundo");
